# %%
import numpy as np
import pandas as pd


data = pd.read_excel('baza.xlsx')
df = pd.DataFrame(data)
df.head(3)
# Out:
#   Date of the test                                   Name of the test  \
# 0       06/10/2023  TOEFL ITP® Level 1 Test + Speaking - Instituti...
# 1       06/10/2023  TOEFL ITP® Level 1 Test + Speaking - Instituti...
# 2       06/10/2023  TOEFL ITP® Level 1 Test + Speaking - Instituti...
#
#                                        Test location  Session id  \
# 0  Qo’qon chet tillar akademiyasi, Kokand, Uzbeki...      380125
# 1  Qo’qon chet tillar akademiyasi, Kokand, Uzbeki...      380125
# 2  Qo’qon chet tillar akademiyasi, Kokand, Uzbeki...      380125
#
#   Registration with voucher (yes/no)  External Candidate ID  \
# 0                                 No                    NaN
# 1                                 No                    NaN
# 2                                 No                    NaN
#
#   Candidate first name Candidate last name Date of birth  \
# 0          NILUFARKHON          ESANALIEVA    16/10/1991
# 1               NOZIMA             URUNOVA    23/04/1991
# ...

# %%
df[['Candidate first name','Candidate last name']].value_counts()
# Out:
# Candidate first name  Candidate last name
# NILUFARKHON           ABDULLAEVA             4
# MUKADDAMKHON          OKHUNOVA               4
# ZEBINISO              ABDURAZAKOVA           4
# MAKHBUBA              AZIMOVA                4
# ISOKJON               KHAMDAMOV              4
#                                             ..
# JAMILAXON             IXTIYORXOJAYEVA        1
# JALOLKHON             MUNAVVAROV             1
# JALGAS                KURMANGALIEV           1
# JAKHONGIR             MASHRABJONOV           1
# ZUMRADKHON            MAKHKAMOVA             1
# Name: count, Length: 418, dtype: int64

# %%
df1 = df[df['Candidate first name']=='NILUFARKHON']
df2 = df1[df1['Candidate last name']== 'ABDULLAEVA']
df2
# Out:
#     Date of the test                                   Name of the test  \
# 186       01/10/2023  TOEFL ITP® Level 1 Test + Speaking - Instituti...
# 193       01/10/2023  TOEFL ITP® Level 1 Test + Speaking - Instituti...
# 207       01/10/2023  TOEFL ITP® Level 1 Test + Speaking - Instituti...
# 251       30/09/2023  TOEFL ITP® Level 1 Test + Speaking - Instituti...
#
#                                          Test location  Session id  \
# 186  Qo’qon chet tillar akademiyasi, Kokand, Uzbeki...      376941
# 193  Qo’qon chet tillar akademiyasi, Kokand, Uzbeki...      376939
# 207  Qo’qon chet tillar akademiyasi, Kokand, Uzbeki...      376938
# 251  Qo’qon chet tillar akademiyasi, Kokand, Uzbeki...      376932
#
#     Registration with voucher (yes/no)  External Candidate ID  \
# 186                                 No                    NaN
# 193                                 No                    NaN
# 207                                 No                    NaN
# ...

# %%
for dt in df2.values:
    print(f'Imtihon kini {dt[0]}\n'
          f'Setion id {dt[3]}')
# Out:
# Imtihon kini 01/10/2023
# Setion id 376941
# Imtihon kini 01/10/2023
# Setion id 376939
# Imtihon kini 01/10/2023
# Setion id 376938
# Imtihon kini 30/09/2023
# Setion id 376932
